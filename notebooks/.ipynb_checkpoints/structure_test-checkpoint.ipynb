# %%
from sim.arena.simple_arena import Arena
from sim.arena.phases import TrainingPhase, EvaluationPhase, ExecutionPhase
from sim.analysis.logger import PrintLogger
from sim.analysis.evaluator import BasicEvaluator
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 from sim.arena.simple_arena import Arena
#       2 from sim.arena.phases import TrainingPhase, EvaluationPhase, ExecutionPhase
# ----> 3 from sim.analytics.logger import PrintLogger
#       4 from sim.analytics.evaluator import BasicEvaluator
#
# ModuleNotFoundError: No module named 'sim.analytics'

# %%
env = GridForestEnv(config)

agents = {
    "collector_0": RLAgent("collector_0", model),
    "cutter_0": GreedyCollector("cutter_0"),
}

arena = Arena(
    env=env,
    agents=agents,
    logger=PrintLogger(),
    evaluator=BasicEvaluator()
)

results = arena.run_phase(ExecutionPhase(episodes=10))
print(results)
