# %%
from arena.simple_arena import Arena
from arena.phases import TrainingPhase, EvaluationPhase, ExecutionPhase
from analysis.logger import PrintLogger
from analysis.evaluator import BasicEvaluator

# %%
env = GridForestEnv(config)

agents = {
    "collector_0": RLAgent("collector_0", model),
    "cutter_0": GreedyCollector("cutter_0"),
}

arena = Arena(
    env=env,
    agents=agents,
    logger=PrintLogger(),
    evaluator=BasicEvaluator()
)

results = arena.run_phase(ExecutionPhase(episodes=10))
print(results)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 env = GridForestEnv(config)
#       3 agents = {
#       4     "collector_0": RLAgent("collector_0", model),
#       5     "cutter_0": GreedyCollector("cutter_0"),
#       6 }
#       8 arena = Arena(
#       9     env=env,
#      10     agents=agents,
#      11     logger=PrintLogger(),
#      12     evaluator=BasicEvaluator()
#      13 )
#
# NameError: name 'GridForestEnv' is not defined
