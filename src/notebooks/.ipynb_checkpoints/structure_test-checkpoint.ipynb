# %%
from arena.arena import Arena
from arena.phases import TrainingPhase, EvaluationPhase, ExecutionPhase
from arena.logger import PrintLogger
from arena.evaluator import BasicEvaluator
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from arena.arena import Arena
#       2 from arena.phases import TrainingPhase, EvaluationPhase
#       3 from arena.logger import PrintLogger
#
# ModuleNotFoundError: No module named 'arena'

# %%
env = GridForestEnv(config)

agents = {
    "collector_0": RLAgent("collector_0", model),
    "cutter_0": GreedyCollector("cutter_0"),
}

arena = Arena(
    env=env,
    agents=agents,
    logger=PrintLogger(),
    evaluator=BasicEvaluator()
)

results = arena.run_phase(ExecutionPhase(episodes=10))
print(results)
